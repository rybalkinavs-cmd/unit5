# %%
ids = {
    'user1': [213, 213, 213, 15, 213],
    'user2': [54, 54, 119, 119, 119],
    'user3': [213, 98, 98, 35]
}

all_geotags = []
for geotags in ids.values():
    all_geotags.extend(geotags)

unique_geotags = set(all_geotags)

print(unique_geotags)
# Результат: {98, 35, 15, 213, 54, 119}
# Out:
# {98, 35, 15, 213, 54, 119}
